# %%
import pandas
cmr=pandas.read_csv("http://modcom.co.ke/bigdata/datasets/Customers.csv")
cmr
# Out:
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...               Tan
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320     PaleVioletRed
# 497  0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...          Cornsilk
# 498  680 Jennifer Lodge Apt. 808\nBrendachester, TX...              Teal
# 499  49791 Rachel Heights Apt. 898\nEast Drewboroug...       DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# ...

# %%
print(cmr.corr())
print(cmr.describe())

array = cmr.values
x=array[:, 2:6]
y=array[:, 6]

from sklearn import model_selection
x_train,x_test, y_train, y_test  = model_selection.train_test_split(x,y,
                                                                     test_size=0.30,
                                                                     random_state=42)

from sklearn.linear_model import LinearRegression
model =LinearRegression ()
model.fit(x_train, y_train) 

predictions=model.predict(x_test)
print (predictions)
from sklearn.metrics import  r2_score
print (r2_score(y_test,  predictions))
amount=model.predict([[32,11,35,2]])
print(amount)
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# ...

# %%
import pandas
cmr1=pandas.read_csv("http://modcom.co.ke/bigdata/datasets/Customers.csv")
cmr1
# Out:
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...               Tan
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320     PaleVioletRed
# 497  0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...          Cornsilk
# 498  680 Jennifer Lodge Apt. 808\nBrendachester, TX...              Teal
# 499  49791 Rachel Heights Apt. 898\nEast Drewboroug...       DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# ...

# %%
#machine learning does not support text in the features e.g avatar
#you have to encode any categorical features to 0, 1,2.......
#you can encode in two ways :Manually and automatically
#automatically is the better choice
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

cmr1['AvatarEncoded'] =encoder.fit_transform(cmr1['Avatar'])
#subset = cmr1[['AvatarEncoded','Avatar']]
#print(subset)
print(cmr1['Avatar'])

array = cmr1.values
x=array[:, 2:6]
y=array[:, 6]

from sklearn import model_selection
x_train,x_test, y_train, y_test  = model_selection.train_test_split(x,y,
                                                                     test_size=0.30,
                                                                     random_state=42)

from sklearn.linear_model import LinearRegression
model =LinearRegression ()
model.fit(x_train, y_train) 

predictions=model.predict(x_test)
print (predictions)
from sklearn.metrics import  r2_score
print (r2_score(y_test,  predictions))
# Out:
# 0                Violet
# 1             DarkGreen
# 2                Bisque
# 3           SaddleBrown
# 4      MediumAquaMarine
#              ...
# 495                 Tan
# 496       PaleVioletRed
# 497            Cornsilk
# 498                Teal
# 499         DarkMagenta
# Name: Avatar, Length: 500, dtype: object
# [403.66993069 542.57756289 427.06591658 502.02460425 410.12143559
#  569.93442508 531.93431341 506.29650969 408.71870658 473.97737105
#  441.46912726 425.33703059 425.1297229  527.61676714 431.45684016
#  424.0769184  575.76543296 484.89856554 458.35936863 481.96502182
#  502.32441491 513.63783554 507.58877002 646.57464283 450.24372141
#  496.27043415 556.40457807 554.95630839 399.64237199 325.84623136
#  532.89783259 478.12238702 501.05701845 305.97335848 505.77244448
#  483.79591969 518.8331528  438.18241857 456.71094234 471.04609461
#  494.44008972 445.31155755 508.78802753 501.04594193 488.83499673
# ...

# %%
# unsupervised learning-you do not know what you are predicting
#you have no target , no Y ,you only have  X
#clustering -putting data into similar groups
import pandas
airlines=pandas.read_csv("http://modcom.co.ke/bigdata/datasets/AirlinesCluster.csv")
airlines

#we cluster 3 columns only
airlines_subset=airlines[['FlightMiles','FlightTrans','DaysSinceEnroll']]
airlines_subset

array=airlines_subset.values
x = array[:,0:3]


from sklearn.cluster import  KMeans
model = KMeans(n_clusters=12,random_state=42)
model.fit(x)

centronoids=model.cluster_centers_
clusters=pandas.DataFrame(centronoids, columns=['FlightMiles','FlightTrans','DaysSinceEnroll'])
print(clusters)

airlines_subset['label']  = model.labels_
airlines_subset = airlines_subset[airlines_subset['label'] == 2]
print(airlines_subset)
# Out:
#      FlightMiles  FlightTrans  DaysSinceEnroll
# 0     174.767881     0.645074      4716.085020
# 1     115.834247     0.489041      2122.865753
# 2    4897.340426    12.510638      2542.595745
# 3     138.624625     0.524024      6084.557057
# 4     115.280179     0.433681      3443.427720
# 5   26458.500000    49.000000      2602.000000
# 6   11325.736842    23.368421      3491.631579
# 7    2426.287770     7.863309      6115.424460
# 8    2340.703704     6.518519      2674.222222
# 9      91.647465     0.361751      1016.430876
# 10   6298.153846    16.282051      6337.307692
# 11    204.193548     0.741935      7555.235732
#       FlightMiles  FlightTrans  DaysSinceEnroll  label
# 1547         4309           12             4469      2
# 1855         4500            9             4166      2
# 1990         3892            6             4394      2
# 2113         4866            3             2626      2
# 2153         3954           12             4010      2
# ...

# %%
import pandas
data=pandas.read_csv("http://modcom.co.ke/bigdatasept/datasets/general.csv")
data

general_subset=general[['BALANCE','BALANCE_FREQUENCY','PURCHASES']]
general_subset

array=general_subset.values
x = array[:,0:3]

from sklearn.cluster import  KMeans
model = KMeans(n_clusters=5,random_state=42)
model.fit(x)

entronoids=model.cluster_centers_
clusters=pandas.DataFrame(centronoids, columns=['BALANCE','BALANCE_FREQUENCY','PURCHASES'])
print(clusters)

general_subset['label']  = model.labels_
general_subset = general_subset[general_subset['label'] == 2]
print(general_subset)
# Out:
#          BALANCE  BALANCE_FREQUENCY    PURCHASES
# 0     174.767881           0.645074  4716.085020
# 1     115.834247           0.489041  2122.865753
# 2    4897.340426          12.510638  2542.595745
# 3     138.624625           0.524024  6084.557057
# 4     115.280179           0.433681  3443.427720
# 5   26458.500000          49.000000  2602.000000
# 6   11325.736842          23.368421  3491.631579
# 7    2426.287770           7.863309  6115.424460
# 8    2340.703704           6.518519  2674.222222
# 9      91.647465           0.361751  1016.430876
# 10   6298.153846          16.282051  6337.307692
# 11    204.193548           0.741935  7555.235732
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  label
# 6      627.260806           1.000000    7091.01      2
# 12    1516.928620           1.000000    3217.99      2
# 21    6369.531318           1.000000    6359.95      2
# 23    3800.151377           0.818182    4248.35      2
# ...
